# %%
# !pip install google-play-scraper
from google_play_scraper import app, reviews, Sort, reviews_all

import pandas as pd
import csv
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
from google_play_scraper import reviews, Sort

scrapreview, _ = reviews(  # ← ambil hanya review-nya
    'com.tokopedia.tkpd',      # ID aplikasi Notion
    lang='id',                 # Bahasa Indonesia
    country='id',              # Negara Indonesia
    sort=Sort.MOST_RELEVANT,   # Urutkan berdasarkan ulasan paling relevan
    count=25000                # Jumlah ulasan yang diambil
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  a801cb94-be3d-459b-9faa-ccb04fe97709  Pengguna Google
# 1  82ab6537-5c22-4c9c-8c19-00f52a4c3612  Pengguna Google
# 2  8106eb5c-aaa4-49de-a2d6-64701826c6b3  Pengguna Google
# 3  98a606a6-be4f-4d28-bfe6-0f68cd27c445  Pengguna Google
# 4  2cc834cc-6dac-4a3a-8d6f-190b353791a6  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  pantes kalian hampir bangkrut, cara kalian men...      1            186
# 1  Makin kesini, makin nggak nyaman belanja di To...      2              0
# 2  aplikasi sering terjadi bug, ketika terjadi ma...      1              3
# 3  Kok otomatis bisa menyalurkan uang ke penjual ...      1             28
# 4  Promo diskon yg ada di etalase tidak sama deng...      1             17
#
#   reviewCreatedVersion                  at  \
# 0              3.304.0 2025-03-20 15:14:43
# 1              3.304.0 2025-03-24 06:45:56
# 2              3.304.0 2025-04-02 11:00:57
# 3              3.305.0 2025-03-29 16:34:08
# 4              3.305.0 2025-04-01 02:41:30
#
#                                         replyContent           repliedAt  \
# 0  Halo Toppers, terima kasih atas rating yang ka... 2025-03-20 15:47:04
# 1  Halo Toppers, terima kasih atas rating yang ka... 2025-03-24 07:07:01
# 2  Hi Toppers, silakan sampaikan kritik/saran ata... 2025-04-02 11:27:03
# 3  Halo Toppers, terima kasih atas rating yang ka... 2025-03-29 17:07:02
# 4  Hi Toppers, silakan sampaikan kritik/saran ata... 2025-04-01 03:00:09
#
#   appVersion
# 0    3.304.0
# 1    3.304.0
# 2    3.304.0
# 3    3.305.0
# 4    3.305.0

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              25000 non-null  object
#  1   userName              25000 non-null  object
#  2   userImage             25000 non-null  object
#  3   content               25000 non-null  object
#  4   score                 25000 non-null  int64
#  5   thumbsUpCount         25000 non-null  int64
#  6   reviewCreatedVersion  18978 non-null  object
#  7   at                    25000 non-null  datetime64[ns]
#  8   replyContent          18848 non-null  object
#  9   repliedAt             18848 non-null  datetime64[ns]
#  10  appVersion            18978 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 2.1+ MB
